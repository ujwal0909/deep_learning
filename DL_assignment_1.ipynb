# %% [markdown]
# <a href="https://colab.research.google.com/github/ujwal0909/deep_learning/blob/main/DL_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 4000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =400
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=10
model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 51s 214ms/step - loss: 0.5166 - accuracy: 0.7294
# Epoch 2/10
# 196/196 [==============================] - 20s 104ms/step - loss: 0.3109 - accuracy: 0.8708
# Epoch 3/10
# 196/196 [==============================] - 11s 55ms/step - loss: 0.2472 - accuracy: 0.9042
# Epoch 4/10
# 196/196 [==============================] - 9s 44ms/step - loss: 0.2078 - accuracy: 0.9219
# Epoch 5/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.1840 - accuracy: 0.9306
# Epoch 6/10
# 196/196 [==============================] - 7s 38ms/step - loss: 0.1498 - accuracy: 0.9443
# Epoch 7/10
# 196/196 [==============================] - 6s 28ms/step - loss: 0.1225 - accuracy: 0.9559
# Epoch 8/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.1037 - accuracy: 0.9638
# Epoch 9/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.0807 - accuracy: 0.9733
# Epoch 10/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.0688 - accuracy: 0.9763

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 11ms/step - loss: 0.4643 - accuracy: 0.8726
# accuracy: 0.8725600242614746
# loss: 0.4642915725708008

# %%
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.0568 - accuracy: 0.9820
# Epoch 2/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.0403 - accuracy: 0.9884
# Epoch 3/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.0405 - accuracy: 0.9872
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.0312 - accuracy: 0.9908
# Epoch 5/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.0303 - accuracy: 0.9911
# Epoch 6/10
# 196/196 [==============================] - 5s 26ms/step - loss: 0.0291 - accuracy: 0.9914
# Epoch 7/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.0201 - accuracy: 0.9945
# Epoch 8/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.0181 - accuracy: 0.9953
# Epoch 9/10
# 196/196 [==============================] - 5s 28ms/step - loss: 0.0176 - accuracy: 0.9949
# Epoch 10/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.0137 - accuracy: 0.9962

# %%
train_loss1 = history.history['loss']
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# # **LSTM**

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 10
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 34s 145ms/step - loss: 0.5089 - accuracy: 0.7458
# Epoch 2/10
# 196/196 [==============================] - 15s 78ms/step - loss: 0.3541 - accuracy: 0.8495
# Epoch 3/10
# 196/196 [==============================] - 9s 48ms/step - loss: 0.2834 - accuracy: 0.8876
# Epoch 4/10
# 196/196 [==============================] - 13s 68ms/step - loss: 0.2247 - accuracy: 0.9138
# Epoch 5/10
# 196/196 [==============================] - 9s 44ms/step - loss: 0.1966 - accuracy: 0.9240
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.1880 - accuracy: 0.9298
# Epoch 7/10
# 196/196 [==============================] - 7s 38ms/step - loss: 0.1608 - accuracy: 0.9397
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.1402 - accuracy: 0.9495
# Epoch 9/10
# 196/196 [==============================] - 7s 37ms/step - loss: 0.1282 - accuracy: 0.9524
# Epoch 10/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.1270 - accuracy: 0.9540

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 11ms/step - loss: 0.5340 - accuracy: 0.8555
# accuracy: 0.8555200099945068
# loss: 0.5340492725372314

# %%
train_loss2 = hist.history['loss']
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# # **RNN**

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 10
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 27s 156ms/step - loss: 0.4939 - accuracy: 0.7583 - val_loss: 0.4069 - val_accuracy: 0.8180
# Epoch 2/10
# 157/157 [==============================] - 16s 99ms/step - loss: 0.2768 - accuracy: 0.8874 - val_loss: 0.5993 - val_accuracy: 0.8004
# Epoch 3/10
# 157/157 [==============================] - 11s 71ms/step - loss: 0.2635 - accuracy: 0.8933 - val_loss: 0.3213 - val_accuracy: 0.8648
# Epoch 4/10
# 157/157 [==============================] - 8s 50ms/step - loss: 0.1860 - accuracy: 0.9299 - val_loss: 0.3572 - val_accuracy: 0.8688
# Epoch 5/10
# 157/157 [==============================] - 7s 47ms/step - loss: 0.1607 - accuracy: 0.9408 - val_loss: 0.3626 - val_accuracy: 0.8514
# Epoch 6/10
# 157/157 [==============================] - 6s 39ms/step - loss: 0.1439 - accuracy: 0.9477 - val_loss: 0.4237 - val_accuracy: 0.8594
# Epoch 7/10
# 157/157 [==============================] - 5s 34ms/step - loss: 0.1129 - accuracy: 0.9592 - val_loss: 0.4410 - val_accuracy: 0.8384
# Epoch 8/10
# 157/157 [==============================] - 7s 46ms/step - loss: 0.1310 - accuracy: 0.9524 - val_loss: 0.6473 - val_accuracy: 0.8412
# Epoch 9/10
# 157/157 [==============================] - 6s 38ms/step - loss: 0.1311 - accuracy: 0.9512 - val_loss: 0.5959 - val_accuracy: 0.8562
# Epoch 10/10
# 157/157 [==============================] - 6s 39ms/step - loss: 0.0793 - accuracy: 0.9743 - val_loss: 0.6299 - val_accuracy: 0.8470

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 2s 11ms/step - loss: 0.6195 - accuracy: 0.8476
# accuracy: 0.847599983215332
# loss: 0.619526743888855

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
